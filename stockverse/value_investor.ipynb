# %%
import os
import sys

# %%
# get the absolute path of the current file
current_dir = os.path.dirname(os.path.abspath("__file__"))
# get the project root (one level up from notebooks/)
project_root = os.path.abspath(os.path.join(current_dir, ".."))
# add project root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# %reload_ext autoreload
# %autoreload 2

from utils.value import magic_formula_rank

# %%
nifty_top_20 = [
    "RELIANCE.NS", "HDFCBANK.NS", "ICICIBANK.NS", "INFY.NS", "AXISBANK.NS", 
    "TCS.NS", "LT.NS", "BHARTIARTL.NS", "SBIN.NS", "ITC.NS", 
    "HINDUNILVR.NS", "BAJFINANCE.NS", "KOTAKBANK.NS", "MARUTI.NS", "M&M.NS", 
    "TATASTEEL.NS", "SUNPHARMA.NS", "HCLTECH.NS", "ADANIENT.NS", "NTPC.NS"
]

# %%
tickers = ["RELIANCE.NS", "TCS.NS", "LT.NS", "BHARTIARTL.NS"]

# %%
df = magic_formula_rank(tickers)
# Out:
# --- All downloads complete ---
# total cash = 2238710022144, total debt = 3745930018816, market_cap = 19274301177856
# EBIT = 1281380000000.0, fixed_assets = 8619420000000.0, working_capital = 455330000000.0
# total cash = 567430021120, total debt = 108210003968, market_cap = 8596938031104
# EBIT = 661270000000.0, fixed_assets = 221250000000.0, working_capital = 700100000000.0
# total cash = 631236001792, total debt = 1340011315200, market_cap = 4716421971968
# EBIT = 269096300000.0, fixed_assets = 197994600000.0, working_capital = 433708100000.0
# total cash = 276804009984, total debt = 1979059011584, market_cap = 11305771597824
# EBIT = 560126000000.0, fixed_assets = 2151549000000.0, working_capital = -1128514000000.0

# %%
df
# Out:
#           Ticker  Earnings Yield       ROC  EY Rank  ROC Rank  Combined Rank
# 0         TCS.NS        0.081260  0.717719      1.0       1.0            2.0
# 1    RELIANCE.NS        0.061660  0.141203      2.0       4.0            6.0
# 2          LT.NS        0.049601  0.425986      3.0       3.0            6.0
# 3  BHARTIARTL.NS        0.043060  0.547514      4.0       2.0            6.0
