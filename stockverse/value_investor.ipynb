# %%
import os
import sys

# %%
# get the absolute path of the current file
current_dir = os.path.dirname(os.path.abspath("__file__"))
# get the project root (one level up from notebooks/)
project_root = os.path.abspath(os.path.join(current_dir, ".."))
# add project root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# %reload_ext autoreload
# %autoreload 2

from utils.value import magic_formula_rank

# %%
nifty_top_20 = [
    "RELIANCE.NS", "HDFCBANK.NS", "ICICIBANK.NS", "INFY.NS", "AXISBANK.NS", 
    "TCS.NS", "LT.NS", "BHARTIARTL.NS", "SBIN.NS", "ITC.NS", 
    "HINDUNILVR.NS", "BAJFINANCE.NS", "KOTAKBANK.NS", "MARUTI.NS", "M&M.NS", 
    "TATASTEEL.NS", "SUNPHARMA.NS", "HCLTECH.NS", "ADANIENT.NS", "NTPC.NS"
]

# %%
tickers = ["RELIANCE.NS", "HDFCBANK.NS", "ICICIBANK.NS"]

# %%
df = magic_formula_rank('RELIANCE.NS')
# Out:
# HTTP Error 404: {"finance":{"result":null,"error":{"code":"Not Found","description":"HTTP 404 Not Found"}}}
# Error for .: Failed to parse json response from Yahoo Finance: {'code': 'Not Found', 'description': 'HTTP 404 Not Found'}
#
# --- All downloads complete ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = magic_formula_rank('RELIANCE.NS')
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\utils\value.py:13, in magic_formula_rank(ticker_list)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\venv\Lib\site-packages\pandas\core\frame.py:880, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     871             mgr = ndarray_to_mgr(
#     872                 data,
#     873                 index,
#    (...)    877                 typ=manager,
#     878             )
#     879     else:
# --> 880         mgr = dict_to_mgr(
#     881             {},
#     882             index,
#     883             columns if columns is not None else default_index(0),
#     884             dtype=dtype,
#     885             typ=manager,
#     886         )
#     887 # For data is scalar
#     888 else:
#     889     if index is None or columns is None:
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\venv\Lib\site-packages\pandas\core\internals\construction.py:450, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     448     index = _extract_index(arrays[~missing])
#     449 else:
# --> 450     index = ensure_index(index)
#     452 # no obvious "empty" int column
#     453 if missing.any() and not is_integer_dtype(dtype):
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\venv\Lib\site-packages\pandas\core\indexes\base.py:7715, in ensure_index(index_like, copy)
#    7713         return Index(index_like, copy=copy, tupleize_cols=False)
#    7714 else:
# -> 7715     return Index(index_like, copy=copy)
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\venv\Lib\site-packages\pandas\core\indexes\base.py:527, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     524         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     526 elif is_scalar(data):
# --> 527     raise cls._raise_scalar_data_error(data)
#     528 elif hasattr(data, "__array__"):
#     529     return cls(np.asarray(data), dtype=dtype, copy=copy, name=name)
#
# File c:\Users\harsher.gill\Documents\GitHub\quant\venv\Lib\site-packages\pandas\core\indexes\base.py:5299, in Index._raise_scalar_data_error(cls, data)
#    5294 @final
#    5295 @classmethod
#    5296 def _raise_scalar_data_error(cls, data):
#    5297     # We return the TypeError so that we can raise it from the constructor
#    5298     #  in order to keep mypy happy
# -> 5299     raise TypeError(
#    5300         f"{cls.__name__}(...) must be called with a collection of some "
#    5301         f"kind, {repr(data) if not isinstance(data, np.generic) else str(data)} "
#    5302         "was passed"
#    5303     )
#
# TypeError: Index(...) must be called with a collection of some kind, 'RELIANCE.NS' was passed

# %%
df
